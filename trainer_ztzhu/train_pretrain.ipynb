# %%
import sys
import os
from pathlib import Path
project_dir = Path(os.path.abspath('')).parent
sys.path.insert(0, project_dir.as_posix())

from tqdm import trange, tqdm
import numpy as np
import torch
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
import train_pretrain

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# %matplotlib inline

# %%
args = train_pretrain.TrainArgs(
    save_weight="pretrain",
    epochs=1,
    hidden_size=512,
    num_hidden_layers=8,
    max_seq_len=512,
    use_amp=True,
    from_weight="none",
    use_wandb=True,
    wandb_entity="ztzhu11",
    dtype="float16",
)
model, tokenizer, train_ds = train_pretrain.train(args, early_return=1)
# Out:
# 所加载Model可训练参数：25.830 M

# %%
train_pretrain.train(args, model, tokenizer, train_ds)
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ztzhu1 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/workspace/minimind/trainer_ztzhu/wandb/run-20251112_061131-sl66hz4f</code>
# Syncing run <strong><a href='https://wandb.ai/ztzhu11/MiniMind/runs/sl66hz4f' target="_blank">MiniMind-26M-pretrain-epoch-1-batchsize-32-lr-0.0005</a></strong> to <a href='https://wandb.ai/ztzhu11/MiniMind' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ztzhu11/MiniMind' target="_blank">https://wandb.ai/ztzhu11/MiniMind</a>
#  View run at <a href='https://wandb.ai/ztzhu11/MiniMind/runs/sl66hz4f' target="_blank">https://wandb.ai/ztzhu11/MiniMind/runs/sl66hz4f</a>
# ...
